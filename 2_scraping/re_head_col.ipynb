# %%
import numpy as np
import pandas as pd

# %%
thesis = pd.read_csv("thesis_summary.csv")
thesis.columns
# Out:
# Index(['Year', 'วิทยาลัยประชากรศาสตร์', 'วิทยาลัยวิทยาศาสตร์สาธารณสุข',
#        'คณะสหเวชศาสตร์', 'คณะสถาปัตยกรรมศาสตร์', 'คณะอักษรศาสตร์',
#        'คณะพาณิชยศาสตร์และการบัญชี', 'คณะนิเทศศาสตร์', 'คณะทันตแพทยศาสตร์',
#        'คณะเศรษฐศาสตร์', 'คณะครุศาสตร์', 'คณะวิศวกรรมศาสตร์',
#        'คณะศิลปกรรมศาสตร์', 'คณะนิติศาสตร์', 'คณะแพทยศาสตร์',
#        'คณะพยาบาลศาสตร์', 'คณะเภสัชศาสตร์', 'คณะรัฐศาสตร์', 'คณะจิตวิทยา',
#        'คณะวิทยาศาสตร์', 'คณะวิทยาศาสตร์การกีฬา', 'คณะสัตวแพทยศาสตร์',
#        'บัณฑิตวิทยาลัย',
#        'วิทยานิพนธ์และสารนิพนธ์ใหม่ จากระบบบริหารจัดการวิทยานิพนธ์ (CU iThesis)',
#        'สถาบันเอเชียศึกษา', 'สถาบันเทคโนโลยีชีวภาพและวิศวกรรมพันธุศาสตร์',
#        'สถาบันไทยศึกษา', 'สถาบันภาษา', 'สำนักงานวิทยทรัพยากร (หอสมุดกลาง)',
#        'วิทยาลัยปิโตรเลียมและปิโตรเคมี', 'สถาบันบัณฑิตบริหารธุรกิจศศินทร์'],
#       dtype='object')

# %%
map_faculty = {"วิทยาลัยประชากรศาสตร์" : "College of Population Studies",
               "วิทยาลัยวิทยาศาสตร์สาธารณสุข": "College of Public Health Sciences",
               "คณะสหเวชศาสตร์": "Faculty of Allied Health Sciences",
               "คณะสถาปัตยกรรมศาสตร์": "Faculty of Architecture",
               "คณะอักษรศาสตร์": "Faculty of Arts",
               "คณะพาณิชยศาสตร์และการบัญชี":"Faculty of Commerce and Accountancy",
               "คณะนิเทศศาสตร์":"Faculty of Communication Arts",
               "คณะทันตแพทยศาสตร์":"Faculty of Dentistry",
               "คณะเศรษฐศาสตร์":"Faculty of Economics",
               "คณะครุศาสตร์": "Faculty of Education",
               "คณะวิศวกรรมศาสตร์":"Faculty of Engineering",
               "คณะศิลปกรรมศาสตร์":"Faculty of Fine and Applied Arts",
               "คณะนิติศาสตร์" : "Faculty of Law",
               "คณะแพทยศาสตร์": "Faculty of Medicine",
               "คณะพยาบาลศาสตร์":"Faculty of Nursing",
               "คณะเภสัชศาสตร์": "Faculty of Phamaceutical Science",
               "คณะรัฐศาสตร์": "Faculty of Political Science",
               "คณะจิตวิทยา":"Faculty of Psychology",
               "คณะวิทยาศาสตร์":"Faculty of Science",
               "คณะวิทยาศาสตร์การกีฬา":"Faculty of Sports Science",
               "คณะสัตวแพทยศาสตร์":"Faculty of Veterinary Science",
               "บัณฑิตวิทยาลัย":"Graduate School",
               "สถาบันเอเชียศึกษา":"Institute of Asian Studies",
               "สถาบันเทคโนโลยีชีวภาพและวิศวกรรมพันธุศาสตร์": "The Institute of Biotechnology and Genetic Engineering",
               "สถาบันไทยศึกษา":"Institute of Thai Studies",
               "สถาบันภาษา":"Language Institute",
               "วิทยาลัยปิโตรเลียมและปิโตรเคมี":"The Petroleum and Petrochemical College",
               "สถาบันบัณฑิตบริหารธุรกิจศศินทร์":"Sasin Graduate Institute of Business Administration"
               }
thesis.rename(columns=map_faculty, inplace=True)
thesis
# Out:
#    Year  College of Population Studies  College of Public Health Sciences  \
# 0  2015                             14                                 41
# 1  2016                              6                                 47
# 2  2017                              6                                 55
#
#    Faculty of Allied Health Sciences  Faculty of Architecture  \
# 0                                 29                       83
# 1                                 20                      114
# 2                                 19                       81
#
#    Faculty of Arts  Faculty of Commerce and Accountancy  \
# 0               97                                   47
# 1               89                                   29
# 2               74                                   28
#
#    Faculty of Communication Arts  Faculty of Dentistry  Faculty of Economics  \
# 0                             61                    29                    33
# ...
